# %%
from styleformer import Styleformer
import torch
import warnings
warnings.filterwarnings("ignore")

# %%
sf = Styleformer(style = 0) 

source_sentences = [
"I am quitting my job",
"Jimmy is on crack and can't trust him",
"What do guys do to show that they like a gal?",
"i loooooooooooooooooooooooove going to the movies.",
"That movie was fucking awesome",
"My mom is doing fine",
"That was funny LOL" , 
"It's piece of cake, we can do it",
"btw - ur avatar looks familiar",
"who gives a crap?",
"Howdy Lucy! been ages since we last met.",
"Dude, this car's dope!",
"She's my bestie from college",
"I kinda have a feeling that he has a crush on you.",
"OMG! It's finger-lickin' good.",
]   

for source_sentence in source_sentences:
    target_sentence = sf.transfer(source_sentence)
    print("-" *100)
    print("[Casual] ", source_sentence)
    print("-" *100)
    if target_sentence is not None:
        print("[Formal] ",target_sentence)
        print()
    else:
        print("No good quality transfers available !")
# Out:
# config.json:   0%|          | 0.00/913 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sf = Styleformer(style = 0)
#       3 source_sentences = [
#       4 "I am quitting my job",
#       5 "Jimmy is on crack and can't trust him",
#    (...)
#      18 "OMG! It's finger-lickin' good.",
#      19 ]
#      21 for source_sentence in source_sentences:
#
# File ~/Documents/Codes/Python Code/ToastMe/Text Conversion/styleformer/styleformer.py:17, in Styleformer.__init__(self, style, ctf_model_tag, ftc_model_tag, atp_model_tag, pta_model_tag, adequacy_model_tag)
#      14 from adequacy import Adequacy
#      16 self.style = style
# ---> 17 self.adequacy = adequacy_model_tag and Adequacy(model_tag=adequacy_model_tag)
#      18 self.model_loaded = False
#      20 if self.style == 0:
#
# File ~/Documents/Codes/Python Code/ToastMe/Text Conversion/styleformer/adequacy.py:5, in Adequacy.__init__(self, model_tag)
#       3 def __init__(self, model_tag='prithivida/parrot_adequacy_model'):
#       4   from transformers import AutoModelForSequenceClassification, AutoTokenizer
# ----> 5   self.adequacy_model = AutoModelForSequenceClassification.from_pretrained(model_tag)
#       6   self.tokenizer = AutoTokenizer.from_pretrained(model_tag)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:561, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     559 elif type(config) in cls._model_mapping.keys():
#     560     model_class = _get_model_class(config, cls._model_mapping)
# --> 561     return model_class.from_pretrained(
#     562         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     563     )
#     564 raise ValueError(
#     565     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     566     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     567 )
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/transformers/modeling_utils.py:3193, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3190     else:
#    3191         # This repo has no safetensors file of any kind, we switch to PyTorch.
#    3192         filename = _add_variant(WEIGHTS_NAME, variant)
# -> 3193         resolved_archive_file = cached_file(
#    3194             pretrained_model_name_or_path, filename, **cached_file_kwargs
#    3195         )
#    3196 if resolved_archive_file is None and filename == _add_variant(WEIGHTS_NAME, variant):
#    3197     # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#    3198     resolved_archive_file = cached_file(
#    3199         pretrained_model_name_or_path,
#    3200         _add_variant(WEIGHTS_INDEX_NAME, variant),
#    3201         **cached_file_kwargs,
#    3202     )
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/transformers/utils/hub.py:398, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     395 user_agent = http_user_agent(user_agent)
#     396 try:
#     397     # Load from URL or cache if already cached
# --> 398     resolved_file = hf_hub_download(
#     399         path_or_repo_id,
#     400         filename,
#     401         subfolder=None if len(subfolder) == 0 else subfolder,
#     402         repo_type=repo_type,
#     403         revision=revision,
#     404         cache_dir=cache_dir,
#     405         user_agent=user_agent,
#     406         force_download=force_download,
#     407         proxies=proxies,
#     408         resume_download=resume_download,
#     409         token=token,
#     410         local_files_only=local_files_only,
#     411     )
#     412 except GatedRepoError as e:
#     413     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/huggingface_hub/file_download.py:1492, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1489         if local_dir is not None:
#    1490             _check_disk_space(expected_size, local_dir)
# -> 1492     http_get(
#    1493         url_to_download,
#    1494         temp_file,
#    1495         proxies=proxies,
#    1496         resume_size=resume_size,
#    1497         headers=headers,
#    1498         expected_size=expected_size,
#    1499         displayed_filename=filename,
#    1500     )
#    1502 if local_dir is None:
#    1503     logger.debug(f"Storing {url} in cache at {blob_path}")
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/huggingface_hub/file_download.py:547, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries)
#     545 new_resume_size = resume_size
#     546 try:
# --> 547     for chunk in r.iter_content(chunk_size=DOWNLOAD_CHUNK_SIZE):
#     548         if chunk:  # filter out keep-alive new chunks
#     549             progress.update(len(chunk))
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
